# %%
print("Name: Althea Marie D. Palentinos")
print("Course: Bachelor of Computer Studies")
print("Section: BSCS3A")
print("Favorite AI Technology: favAI")
print("Future AI Project: futureProj")
# Out:
# Name: Althea Marie D. Palentinos
# Course: Bachelor of Computer Studies
# Section: BSCS3A
# Favorite AI Technology: favAI
# Future AI Project: futureProj
